# %%
import json
import re
import os
import pandas as pd
import numpy as np

# %%
for file in os.listdir("/home/jasmine/PROJECTS/lyriguessr/artists/radiohead"):
    if file.endswith(".json"):
        print(file)
# Out:
# OK_Computer.json
# The_Bends.json
# A_Moon_Shaped_Pool.json
# The_King_Of_Limbs.json
# In_Rainbows.json
# Kid_A.json
# Hail_To_the_Thief.json
# Pablo_Honey.json
# Amnesiac.json

# %%
json_file = open('OK_Computer.json')
data = json.load(json_file)

# %%
data
# Out:
# {'_type': 'album',
#  'api_path': '/albums/17915',
#  'cover_art_thumbnail_url': 'https://images.genius.com/49feb9d39f5b2e62ebd618a46633168a.300x300x1.png',
#  'cover_art_url': 'https://images.genius.com/49feb9d39f5b2e62ebd618a46633168a.1000x1000x1.png',
#  'full_title': 'OK Computer by Radiohead',
#  'id': 17915,
#  'name': 'OK Computer',
#  'name_with_artist': 'OK Computer (artist: Radiohead)',
#  'release_date_components': {'year': 1997, 'month': 5, 'day': 21},
#  'release_date_for_display': 'May 21, 1997',
#  'url': 'https://genius.com/albums/Radiohead/Ok-computer',
#  'artist': {'_type': 'artist',
#   'api_path': '/artists/604',
#   'header_image_url': 'https://images.genius.com/541c8084c75625c6466268d297022dcb.1000x165x1.png',
#   'id': 604,
#   'image_url': 'https://images.genius.com/66ba802a239641b0cd063444772490f5.900x900x1.jpg',
#   'index_character': 'r',
#   'is_meme_verified': False,
#   'is_verified': False,
#   'name': 'Radiohead',
#   'slug': 'Radiohead',
# ...

# %%
data["tracks"]
# Out:
# [{'number': 1,
#   'song': {'_type': 'song',
#    'annotation_count': 7,
#    'api_path': '/songs/80540',
#    'artist_names': 'Radiohead',
#    'full_title': 'Airbag by\xa0Radiohead',
#    'header_image_thumbnail_url': 'https://images.genius.com/d114d8bb4c110efe7a773544694169a1.300x300x1.png',
#    'header_image_url': 'https://images.genius.com/d114d8bb4c110efe7a773544694169a1.1000x1000x1.png',
#    'id': 80540,
#    'instrumental': False,
#    'lyrics_owner_id': 46705,
#    'lyrics_state': 'complete',
#    'lyrics_updated_at': 1683334615,
#    'path': '/Radiohead-airbag-lyrics',
#    'primary_artist_names': 'Radiohead',
#    'pyongs_count': 47,
#    'relationships_index_url': 'https://genius.com/Radiohead-airbag-sample',
#    'release_date_components': {'year': 1997, 'month': 5, 'day': 21},
#    'release_date_for_display': 'May 21, 1997',
#    'release_date_with_abbreviated_month_for_display': 'May. 21, 1997',
# ...

# %%
songs = [track_dict[]]
